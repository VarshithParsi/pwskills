# %% [markdown]
# #THEORETICAL QUESTIONS

# %% [markdown]
# 1. What is the difference between a function and a method in Python?
# Ans - A function is a block of code that performs a specific task and can be called independently, while a method is a function that is associated with an object and can be called on that object.

# %% [markdown]
# 2. Explain the concept of function arguments and parameters in Python.
# Ans - Parameters are the variables listed in the function definition, while arguments are the values passed to the function when it is called.

# %% [markdown]
# 3. What are the different ways to define and call a function in Python?
# Ans - Functions can be defined using the 'def' keyword followed by the function name and parameters. They can be called by usingthe    function name followed by parentheses and arguments.

# %% [markdown]
# 4. What is the purpose of the `return` statement in a Python function?
# Ans - The `return` statement is used to exit a function and return a value to the caller.

# %% [markdown]
# 5. What are iterators in Python and how do they differ from iterables?
# Ans - Iterators are objects that can be iterated over, while iterables are objects that can return an iterator. Iterators implement the `__iter__()` and `__next__()` methods.

# %% [markdown]
# 6. Explain the concept of generators in Python and how they are defined.
# Ans - Generators are functions that return an iterator and allow you to iterate over a sequence of values. They are defined using the 'yield' keyword.

# %% [markdown]
# 7. What are the advantages of using generators over regular functions?
# Ans - Generators are memory-efficient and can produce values one at a time, allowing for lazy evaluation and improved performance.

# %% [markdown]
# 8. What is a lambda function in Python and when is it typically used?
# Ans - A lambda function is a small anonymous function defined using the 'lambda' keyword. It is typically used for short, simple functions that are used only once or passed as arguments.

# %% [markdown]
# 9. Explain the purpose and usage of the `map()` function in Python.
# Ans - The `map()` function applies a given function to each item in an iterable and returns an iterator with the results.

# %% [markdown]
# 10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?
# Ans - The `map()` function applies a function to each item in an iterable, `reduce()` applies a function cumulatively to the items in an iterable, and `filter()` returns an iterator with items that satisfy a given condition.

# %% [markdown]
# 11) Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given
# list:[47,11,42,13];
#
# import matplotlib.pyplot as plt
# import matplotlib.image as mpimg
#
# img = mpimg.imread('image.jfif') #Replace "image.jpg" with the path of your image
# plt.imshow(img)
# plt.axis('off')
# plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
 
img = mpimg.imread('image.jfif')
plt.imshow(img)
plt.axis('off')
plt.show()

# %% [markdown]
# ##CODING QUESTIONS

# %%
#1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in
#the list

def sum_of_even_numbers(numbers):
    total = 0
    for num in numbers:
        if num % 2 == 0:
            total += num
    return total


a = [1, 2, 4, 7, 8]
result = sum_of_even_numbers(a)
print("Sum of even numbers:", result)
# Out:
# Sum of even numbers: 14

# %%
# 2. Create a Python function that accepts a string and returns the reverse of that string
def reverse_string(s):
    return s[::-1]

s="Hello"
b=reverse_string(s)
print(b)
# Out:
# olleH

# %%
# 3. Implement a Python function that takes a list of integers and returns a new list containing the squares of
#each number.
def square_list(a):
    return [i ** 2 for i in a]

# Example usage
input_list = [1, 2, 3, 4, 5]
squared_list = square_list(input_list)
print(squared_list)
# Out:
# [1, 4, 9, 16, 25]

# %%
# 4)Write a Python function that checks if a given number is prime or not from 1 to 200.
def is_prime(n):
    if n <= 1:
        return False  
    for i in range(2, int(n ** 0.5) + 1):  
        if n % i == 0:
            return False  
    return True  

print(is_prime(7))  
print(is_prime(10))
# Out:
# True
# False

# %%
# 5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of
#terms.
class FibonacciIterator:
    def __init__(self, max_terms):
        self.max_terms = max_terms
        self.count = 0
        self.a, self.b = 0, 1

    def __iter__(self):
        return self

    def __next__(self):
        if self.count >= self.max_terms:
            raise StopIteration
        if self.count == 0:
            self.count += 1
            return 0
        elif self.count == 1:
            self.count += 1
            return 1
        else:
            self.a, self.b = self.b, self.a + self.b
            self.count += 1
            return self.a

fib = FibonacciIterator(10)
for num in fib:
    print(num)
# Out:
# 0
# 1
# 1
# 1
# 2
# 3
# 5
# 8
# 13
# 21

# %%
# 6)Write a generator function in Python that yields the powers of 2 up to a given exponent.
def powers_of_two(n):
    for i in range(n + 1):
        yield 2 ** i

for power in powers_of_two(5):
    print(power)
# Out:
# 1
# 2
# 4
# 8
# 16
# 32

# %%
# 7. Implement a generator function that reads a file line by line and yields each line as a string.
def read_file_line_by_line(file_path):
    with open(file_path, 'r') as file:
        for line in file:
            yield line.strip()

# %%
# 8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple
data = [(1, 3), (2, 1), (4, 2), (5, 0)]
sorted_data = sorted(data, key=lambda x: x[1])
print(sorted_data)
# Out:
# [(5, 0), (2, 1), (4, 2), (1, 3)]

# %%
# 9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit

celsius = [0, 20, 37, 100]
fahrenheit = list(map(lambda c: (c * 9/5) + 32, celsius))
print(fahrenheit)
# Out:
# [32.0, 68.0, 98.6, 212.0]

# %%
# 10. Create a Python program that uses `filter()` to remove all the vowels from a given string.
def remove_vowels(s):
    return ''.join(filter(lambda x: x.lower() not in 'aeiou', s))

# Example usage
text = "Hello World"
result = remove_vowels(text)
print(result)
# Out:
# Hll Wrld

# %%
# 11) Python program for the described accounting routine without map and lambda

orders = [
    (34587, "Learning Python, Mark Lutz", 4, 40.95),
    (98762, "Programming Python, Mark Lutz", 5, 56.80),
    (77226, "Head First Python, Paul Barry", 3, 32.95),
    (88112, "Einführung in Python3, Bernd Klein", 3, 24.99)
]

# Function to calculate the total price and apply the condition
calculate_total = lambda order: (order[0], order[2] * order[3] if order[2] * order[3] >= 100 else order[2] * order[3] + 10)

# Apply the function to each order using map
order_totals = list(map(calculate_total, orders))

# Print the result
print(order_totals)
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85000000000001), (88112, 84.97)]
